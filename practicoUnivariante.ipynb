# %% [markdown]
# # Practico Univariado

# %% [markdown]
# ##### Consigna

# %% [markdown]
# Realizar un analisis univariado de datos, teniendo en cuenta las caracterizticas de la observacion. generando al menos 3 graficos.-

# %% [markdown]
# - Camada: 18195
# - Tutor: Rober Ribero
# - Alumno: Ferreri, Gustavo

# %% [markdown]
# ##### Desarrollo

# %%
#Importamos las librerias
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Cargamos el DataFrame, eliminando la ultima columna recidual con datos vacios
data = pd.read_csv('AnnualTicketSales.csv', na_filter=True, skip_blank_lines=True).drop(df.columns[[-1]], axis ='columns')

# %%
#Colocamos el Anno como indice del DF
df = pd.DataFrame(data, index=data.index).set_index('YEAR')

# %%
#Mostramos la tabla para observar como esta la integridad de la tabla y sus datos
df
# Out:
#         TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# YEAR
# 2021    42,37,74,881   $3,881,777,912                      $3,881,777,912
# 2020    22,36,38,958   $2,048,534,616                      $2,048,534,616
# 2019  1,22,85,41,629  $11,253,443,955                     $11,253,444,050
# 2018  1,31,15,36,128  $11,948,096,650                     $12,013,670,952
# 2017  1,22,56,39,761  $10,993,991,460                     $11,226,860,216
# 2016  1,30,25,56,378  $11,267,115,924                     $11,931,416,424
# 2015  1,32,33,56,776  $11,155,900,636                     $12,121,948,075
# 2014  1,25,74,02,920  $10,272,985,008                     $11,517,810,744
# 2013  1,33,91,68,926  $10,887,446,341                     $12,266,787,382
# 2012  1,38,09,21,942  $10,992,141,616                     $12,649,244,986
# 2011  1,28,29,15,168  $10,173,519,704                     $11,751,502,955
# 2010  1,32,85,49,021  $10,482,254,025                     $12,169,509,032
# ...

# %%
#Funcion para remover signo
def limpiarSigno (data, *signo):
    for i in range(len(signo)):
        for j in data.columns:
            if data[j].dtypes == 'object':
                data[j] = data[j].str.replace(signo[i],'', regex=True)

# %%
#Aplicamos la funcion
limpiarSigno(df, ',', '$')
df
# Out:
#      TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# YEAR
# 2021    423774881       3881777912                          3881777912
# 2020    223638958       2048534616                          2048534616
# 2019   1228541629      11253443955                         11253444050
# 2018   1311536128      11948096650                         12013670952
# 2017   1225639761      10993991460                         11226860216
# 2016   1302556378      11267115924                         11931416424
# 2015   1323356776      11155900636                         12121948075
# 2014   1257402920      10272985008                         11517810744
# 2013   1339168926      10887446341                         12266787382
# 2012   1380921942      10992141616                         12649244986
# 2011   1282915168      10173519704                         11751502955
# 2010   1328549021      10482254025                         12169509032
# ...

# %%
df.shape
# Out:
# (27, 4)

# %%
df.describe()
# Out:
#        TICKETS SOLD TOTAL BOX OFFICE TOTAL INFLATION ADJUSTED BOX OFFICE  \
# count            27               27                                  27
# unique           27               27                                  27
# top       423774881       3881777912                          3881777912
# freq              1                1                                   1
#
#        AVERAGE TICKET PRICE
# count                    27
# unique                   25
# top                    9.16
# freq                      3

# %%
df.dtypes
# Out:
# TICKETS SOLD                           object
# TOTAL BOX OFFICE                       object
# TOTAL INFLATION ADJUSTED BOX OFFICE    object
# AVERAGE TICKET PRICE                   object
# dtype: object

# %%
# Modificamos los tipos de las columnas
df['TICKETS SOLD'] = df['TICKETS SOLD'].astype('int64')
df['TOTAL BOX OFFICE'] = df['TOTAL BOX OFFICE'].astype('int64')
df['TOTAL INFLATION ADJUSTED BOX OFFICE'] = df['TOTAL INFLATION ADJUSTED BOX OFFICE'].astype('int64')
df['AVERAGE TICKET PRICE'] = df['AVERAGE TICKET PRICE'].astype(float)

# %%
df.dtypes
# Out:
# TICKETS SOLD                             int64
# TOTAL BOX OFFICE                         int64
# TOTAL INFLATION ADJUSTED BOX OFFICE      int64
# AVERAGE TICKET PRICE                   float64
# dtype: object

# %%
#Mostramos los datos
plt.plot(df['AVERAGE TICKET PRICE'])
plt.title('Evolucion del precio promedio')
plt.show()

# %%
#Mostramos los datos
plt.bar(df.index, df['TICKETS SOLD'])
plt.title('Ticket vendidos')
plt.show()

# %%
#Mostramos los datos
plt.scatter(df.index, df['TOTAL BOX OFFICE'])
plt.title('Taquilla')
plt.show()
